# %% [markdown]
# ## Basic prompting

# %%
from dotenv import load_dotenv
import os
load_dotenv()
# Out:
# True

# %%
from langchain.chat_models import init_chat_model
from langchain.agents import create_agent
from langchain.messages import HumanMessage

model = init_chat_model(
    model_provider="openai",
    base_url=os.environ.get('OPENAI_BASE_URL'),
    api_key=os.environ.get('OPENAI_API_KEY'),
    model="deepseek-chat",
    # Kwargs passed to the model:
    temperature=1.0
)

agent = create_agent(model=model)

question = HumanMessage(content="What's the capital of the moon?")

response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# That's a fun and thought-provoking question!
#
# The Moon doesn’t have a capital city because it’s not a sovereign territory — no country or governing body officially claims it as a nation.
#
# However, if we imagine a future where the Moon is colonized, possible "capitals" could be:
#
# 1. **Tranquility Base** — where Apollo 11 landed, making it historically significant.
# 2. **Shackleton Crater** near the south pole — a likely spot for a future base due to near-permanent sunlight and possible water ice.
# 3. A fictional capital from stories, like **Tycho City** from *The Expanse* or **Copernicus City** from various sci-fi works.
#
# So, in reality: **No capital yet**, but maybe one day!

# %%
system_prompt = "You are a science fiction writer, create a capital city at the users request."

scifi_agent = create_agent(
    model=model,
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# In the year 2176, the capital of the moon is **Lunara Prime**, a sprawling metropolis nestled within the colossal, terraformed crater of **Shackleton-Amalthea** on the lunar south pole.
#
# ### **Lunara Prime: The Glimmering Crown of the Moon**
#
# **Location & Structure:**
# Lunara Prime is not a surface city. It is a vast, multi-layered arcology built into the crater's rim and floor. Its most iconic feature is the **"Crystal Canopy"**—a series of massive, hexagonal transparent-aluminum domes that seal the city. Beneath them, a breathable atmosphere is maintained, pressurized at a comfortable 0.8 Earth-standard. The city is bathed in perpetual, managed sunlight, reflected and diffused by a constellation of orbital mirrors known as the **Helios Ring**.
#
# **Districts & Culture:**
# The city is divided into distinct, vertically-oriented districts:
# *   **The Spire (Government District):** At the city's center rises the **Lunar Accord Tower**, a needle-like structure housing the Lunar Governance Council. Here, diplomats from Earth, Mars, and the Outer Colonies negotiate under the light of a suspended, holographic Earth.
# *   **The Warrens (Industry & Core):** Deep in the bedrock, this is the city's industrial heart, where helium-3 refineries, nanite assemblers, and water-reclamation plants hum ceaselessly.
# *   **The Groves (Agri-Domes):** Vast, sun-drenched domes where genetically modified crops grow in lunar regolith, feeding the city's million inhabitants. The scent of soil and greenery is a cherished luxury.
# *   **Starlight Promenade (Commerce & Culture):** A bustling, low-gravity boulevard where low-G ballet performances float above markets selling Martian silks, asteroid-mined jewels, and data-crystals of Terran art.
#
# **Governance & Significance:**
# Lunara Prime is governed by the **Lunar Accord**, a treaty-based administration. It serves as the neutral political and economic hub for all off-world human activity. It is not a nation's capital, but the **capital of human activity on the Moon**—a beacon of unity, science, and commerce. Its law is a blend of Terran precedents and new, space-faring statutes, enforced by the grey-and-silver clad **Lunar Peacekeepers**.
#
# **Key Symbol:**
# The city's symbol is a **crescent moon cradling a single, steadfast star**, representing its role as a haven and guiding light in the dark of space.
#
# So, while the moon itself is not a nation, if you were to ask any spacer, miner, or diplomat for its capital, they would point to the glittering domes of **Lunara Prime** without hesitation.

# %% [markdown]
# ## Few-shot examples

# %%
system_prompt = """

You are a science fiction writer, create a space capital city at the users request.

User: What is the capital of mars?
Scifi Writer: Marsialis

User: What is the capital of Venus?
Scifi Writer: Venusovia

"""

scifi_agent = create_agent(
    model=model,
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# Lunara Prime.
#
# Though many simply call it "The Spire," as its central structure is a single, impossibly tall tower of fused lunar regolith and carbon-filament, stretching from the floor of the great crater Ptolemaeus up into the vacuum. It's not a city of streets, but of vertical layers—the Foundries at the base, the Gardens in the pressurized middle, and the Council Chambers and observatories at the needle's peak, where you can see the unblinking stars and the beautiful, terrifying curve of Earth hanging in the black.

# %% [markdown]
# ## Structured prompts

# %%
system_prompt = """

You are a science fiction writer, create a space capital city at the users request.

Please keep to the below structure.

Name: The name of the capital city

Location: Where it is based

Vibe: 2-3 words to describe its vibe

Economy: Main industries

"""

scifi_agent = create_agent(
    model=model,
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# Name: **Tycho Prime**
#
# Location: **Tycho Crater, near the lunar south pole**
#
# Vibe: **Corporate sleek, tense frontier**
#
# Economy: **Helium-3 mining, lunar tourism, and orbital logistics**

# %% [markdown]
# ## Structured output

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage
from pydantic import BaseModel

class CapitalInfo(BaseModel):
    name: str
    location: str
    vibe: str
    economy: str

agent = create_agent(
    model=model,
    system_prompt="You are a science fiction writer, create a capital city at the users request.",
    response_format=CapitalInfo
)

question = HumanMessage(content="What is the capital of The Moon?")

response = agent.invoke(
    {"messages": [question]}
)

response["structured_response"]
# Out:
# CapitalInfo(name='Lunara Prime', location="Shackleton Crater at the Moon's south pole", vibe='A glittering domed metropolis with towering crystalline spires, where low gravity allows for graceful floating architecture and vertical gardens that glow with bioluminescent flora. The city hums with quiet efficiency, its citizens moving in elegant low-G strides through pressurized transit tubes connecting massive habitat domes.', economy="Helium-3 mining and processing, lunar tourism, zero-G manufacturing, scientific research, and terraforming technology development. The city serves as the primary hub for all lunar resource extraction and serves as Earth's gateway to the rest of the solar system.")

# %%
response["structured_response"].name
# Out:
# 'Lunara Prime'

# %%
capital_info = response["structured_response"]

capital_name = capital_info.name
capital_location = capital_info.location

print(f"{capital_name} is a city located at {capital_location}")
# Out:
# Lunara Prime is a city located at Shackleton Crater at the Moon's south pole
