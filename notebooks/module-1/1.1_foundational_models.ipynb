# %%
from dotenv import load_dotenv
import os

load_dotenv()
# Out:
# True

# %% [markdown]
# ## Initialising and invoking a model

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model(
    model_provider="openai",
    base_url=os.environ.get('OPENAI_BASE_URL'),
    api_key=os.environ.get('OPENAI_API_KEY'),
    model="DeepSeek-V3.1"
)

# %%
response = model.invoke("What's the capital of the Moon?")

response
# Out:
# AIMessage(content='The capital of the Moon is a concept from fiction and future planning, as there is no official capital today. Here are the most common answers:\n\n### 1. The Fictional Answer: Tycho City\nIn the popular novel and TV series **"The Expanse,"** the main city on the Moon is **Tycho City**. It\'s a major administrative and industrial hub located in the Tycho Crater.\n\n### 2. The Futuristic/Planned Answer: Shackleton City or Tycho City (in Concept)\nIn real-world proposals for future lunar colonization, one of the most frequently suggested locations for a capital is near the **Shackleton Crater** at the Moon\'s south pole. This area has near-continuous sunlight (for solar power) and potential water ice deposits in permanently shadowed craters. A city there might logically become a "capital."\n\n### 3. The Realistic Answer: None\nCurrently, no country has sovereignty over any part of the Moon, as per the **Outer Space Treaty of 1967**. The Moon has no cities, no population, and therefore no capital.\n\n**In short:** There isn\'t one, but if you\'re looking for a name from science fiction, **Tycho City** is the most famous answer.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 268, 'prompt_tokens': 15, 'total_tokens': 283, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_provider': 'openai', 'model_name': 'DeepSeek-V3.1-Terminus', 'system_fingerprint': None, 'id': 'chatcmpl-b0ec2adc40f2a323', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019d2469-78d4-7eb3-b455-c7b7ec024087-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 15, 'output_tokens': 268, 'total_tokens': 283, 'input_token_details': {}, 'output_token_details': {}})

# %%
print(response.content)
# Out:
# The capital of the Moon is a concept from fiction and future planning, as there is no official capital today. Here are the most common answers:
#
# ### 1. The Fictional Answer: Tycho City
# In the popular novel and TV series **"The Expanse,"** the main city on the Moon is **Tycho City**. It's a major administrative and industrial hub located in the Tycho Crater.
#
# ### 2. The Futuristic/Planned Answer: Shackleton City or Tycho City (in Concept)
# In real-world proposals for future lunar colonization, one of the most frequently suggested locations for a capital is near the **Shackleton Crater** at the Moon's south pole. This area has near-continuous sunlight (for solar power) and potential water ice deposits in permanently shadowed craters. A city there might logically become a "capital."
#
# ### 3. The Realistic Answer: None
# Currently, no country has sovereignty over any part of the Moon, as per the **Outer Space Treaty of 1967**. The Moon has no cities, no population, and therefore no capital.
#
# **In short:** There isn't one, but if you're looking for a name from science fiction, **Tycho City** is the most famous answer.

# %%
from pprint import pprint

pprint(response.response_metadata)
# Out:
# {'finish_reason': 'stop',
#  'id': 'chatcmpl-b0ec2adc40f2a323',
#  'logprobs': None,
#  'model_name': 'DeepSeek-V3.1-Terminus',
#  'model_provider': 'openai',
#  'system_fingerprint': None,
#  'token_usage': {'completion_tokens': 268,
#                  'completion_tokens_details': None,
#                  'prompt_tokens': 15,
#                  'prompt_tokens_details': None,
#                  'total_tokens': 283}}

# %% [markdown]
# ## Customising your Model

# %%
model = init_chat_model(
    model_provider="openai",
    base_url=os.environ.get('OPENAI_BASE_URL'),
    api_key=os.environ.get('OPENAI_API_KEY'),
    model="DeepSeek-V3.1",
    # Kwargs passed to the model:
    temperature=1.0
)

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# That's a classic joke or trick question! The Moon doesn't have a capital city because it is not a country; it's a natural satellite with no sovereign government.
#
# Historic or proposed bases, like the American Apollo landing sites or the future Artemis Base Camp, could be considered the closest equivalents, but there is no officially recognized capital.
#
# So the usual punchline is: **The Moon doesn't have a capital.**

# %% [markdown]
# ## Model Providers

# %% [markdown]
# https://docs.langchain.com/oss/python/integrations/chat

# %%
model = init_chat_model(model="claude-sonnet-4-5")

response = model.invoke("What's the capital of the Moon?")
print(response.content)

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")

response = model.invoke("What's the capital of the Moon?")
print(response.content)

# %% [markdown]
# ## Initialising and invoking an agent

# %%
from langchain.agents import create_agent

agent = create_agent(model=model)

# %%
agent = create_agent(model="DeepSeek-V3.1")

# %%
agent = create_agent("gpt-5-nano")

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?")]}
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='61d9b803-826f-4c81-ac1e-0e3ab444b2c9'),
#               AIMessage(content='That\'s a fun question! The Moon doesn\'t have a capital city because it\'s not a country and has no permanent population or government.\n\nWhile there are ambitious plans for lunar bases and settlements from agencies like NASA (Artemis Program) and others, no official capital exists yet.\n\nIf you\'re imagining a future where the Moon is colonized, the first permanent settlement would likely become the de facto capital! Some science fiction stories have even given it names like "Tranquility Base" (after the Apollo 11 landing site) or "Armstrong City."', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 114, 'prompt_tokens': 15, 'total_tokens': 129, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_provider': 'openai', 'model_name': 'DeepSeek-V3.1-Terminus', 'system_fingerprint': None, 'id': 'chatcmpl-a731edbe74f84f5e', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019d2477-4ed4-7aa1-9bb1-565232f94198-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 15, 'output_tokens': 114, 'total_tokens': 129, 'input_token_details': {}, 'output_token_details': {}})]}

# %%
print(response['messages'][-1].content)
# Out:
# That's a fun question! The Moon doesn't have a capital city because it's not a country and has no permanent population or government.
#
# While there are ambitious plans for lunar bases and settlements from agencies like NASA (Artemis Program) and others, no official capital exists yet.
#
# If you're imagining a future where the Moon is colonized, the first permanent settlement would likely become the de facto capital! Some science fiction stories have even given it names like "Tranquility Base" (after the Apollo 11 landing site) or "Armstrong City."

# %%
from langchain.messages import AIMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?"),
    AIMessage(content="The capital of the Moon is Luna City."),
    HumanMessage(content="Interesting, tell me more about Luna City")]}
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='2a56745f-4a43-47dd-ab99-d4ad55d2404d'),
#               AIMessage(content='The capital of the Moon is Luna City.', additional_kwargs={}, response_metadata={}, id='b3cc2988-d7d8-4b2a-909a-f51260ca6ee4', tool_calls=[], invalid_tool_calls=[]),
#               HumanMessage(content='Interesting, tell me more about Luna City', additional_kwargs={}, response_metadata={}, id='e5cd7563-63f1-4fd8-a120-606f886c45ff'),
#               AIMessage(content='Of course! Since "Luna City" is a fictional concept, let\'s explore what this capital of the Moon would likely be like, based on science and our current understanding of what a permanent lunar settlement would require.\n\nHere\'s a detailed profile of the hypothetical Luna City:\n\n### **Official Designation: Luna City**\n*(Often just called "Luna" or "The City")*\n\n---\n\n### **Location: Shackleton Crater, Lunar South Pole**\nThis is the most scientifically plausible location for a major settlement. The rim of Shackleton Crater is bathed in near-permanent sunlight for solar power, while the crater\'s deep interior contains **permanently shadowed regions (PSRs)** believed to hold vast quantities of water ice. This ice is crucial for life support (water and oxygen) and for creating rocket fuel (liquid hydrogen and oxygen).\n\n### **Architecture and Structure: Below the Surface**\nTo protect inhabitants from the Moon\'s harsh environment—including **solar radiation, cosmic rays, micrometeorites, and extreme temperature swings** (from 127°C/260°F in the sun to -173°C/-280°F in the shade)—most of Luna City would be built underground or within lava tubes (natural underground tunnels formed by ancient volcanic activity).\n\n*   **The Citadel:** The central, pressurized core of the city. It consists of interconnected modules, some buried and others reinforced with meters-thick lunar regolith (soil). These modules would contain living quarters, command centers, agricultural bays, and public spaces.\n*   **Surface Structures:** The surface would be dotted with observatories, communication arrays, landing pads, mining operations, and the entrances to the underground network. Many surface operations would be automated or handled by robots.\n\n### **Population: A Global Melting Pot**\nThe population would be small by Earth standards, starting with a few hundred scientists, engineers, and technicians, and potentially growing to a few thousand. It would be an international community, representing the space agencies and private companies that funded its construction. The official languages would likely be a mix of English, Russian, Mandarin, and others, with a new "Lunarian" dialect possibly emerging over time.\n\n### **Economy and Purpose**\nLuna City would serve multiple critical functions:\n\n1.  **Scientific Research:** A premier lab for astronomy, planetary science, and studying the long-term effects of living in low gravity.\n2.  **Gateway to the Solar System:** Because of the Moon\'s low gravity, it is far more fuel-efficient to launch missions to Mars and beyond from the Moon than from Earth. Luna City would be the primary hub for refueling and constructing spacecraft.\n3.  **Industrial Hub:** Mining lunar resources like Helium-3 (a potential fuel for future fusion reactors) and water ice for propellant.\n4.  **Tourism:** An exclusive destination for extremely wealthy civilians and researchers.\n\n### **Daily Life in Luna City**\n*   **Low Gravity (1/6th of Earth\'s):** Walking would be a slow, bouncing gait. Sports and exercise would be adapted, and daily rigorous workouts would be mandatory to combat muscle and bone density loss.\n*   **Agriculture:** Food would be grown in highly controlled, circular hydroponic and aeroponic farms under specialized LED lights. Diets would be heavily plant-based, with lab-grown meat as a supplement.\n*   **Government:** Initially, it would be governed by a consortium of terrestrial nations (like the Antarctic Treaty system). As it grows more self-sufficient, it might develop its own unique form of governance, a topic famously explored in Robert A. Heinlein\'s novel *The Moon Is a Harsh Mistress*.\n*   **Culture:** A unique culture would blend the traditions of its international crew with new customs born from their extraordinary environment. Art, music, and holidays would reflect life on a new world, perhaps celebrating "Sunrise over Shackleton" (which happens only ...

# %% [markdown]
# ## Streaming Output

# %%
for token, metadata in agent.stream(
    {"messages": [HumanMessage(content="Tell me all about Luna City, the capital of the Moon")]},
    stream_mode="messages"
):

    # token is a message chunk with token content
    # metadata contains which node produced the token
    
    if token.content:  # Check if there's actual content
        print(token.content, end="", flush=True)  # Print token
# Out:
# Of course! Let's take a journey to **Luna City**, the bustling, vibrant, and awe-inspiring capital of the Moon. What follows is a detailed look into this marvel of human engineering, based on a synthesis of current scientific plans, science fiction visions, and plausible extrapolation.
#
# ---
#
# ### **Luna City: The Crown Jewel of the Moon**
#
# Luna City, also known as **Selene City** (from the Greek goddess of the moon), is not just a settlement; it is a symbol of humanity's permanent expansion into the cosmos. Established in the latter half of the 21st century, it has grown from a series of connected modules into a sprawling, pressurized metropolis under the lunar sky.
#
# #### **1. Location: The Strategic Choice**
#
# Luna City is strategically located at the **lunar south pole**, specifically on the rim of the **Shackleton Crater**. This location was chosen for several critical reasons:
#
# *   **Near-Permanent Sunlight:** The rim of the crater experiences sunlight for over 80% of the lunar day (which is about 14 Earth days long). This provides a near-continuous source of solar energy.
# *   **Peaks of Eternal Light:** Nearby mountain peaks are illuminated almost constantly, making them ideal spots for powerful solar power arrays.
# *   **Water Ice in Permanently Shadowed Regions (PSRs):** The bottom of Shackleton Crater is in perpetual darkness, creating a "cold trap" where water ice and other volatile compounds have accumulated over billions of years. This ice is the lifeblood of the city, providing water for drinking, agriculture, and, when split into hydrogen and oxygen, breathable air and rocket fuel.
# *   **Stable Thermal Environment:** The extreme temperature swings between lunar day (127°C) and night (-173°C) are moderated at the poles, making construction and thermal management easier.
#
# #### **2. Architecture and Structure: Living in a Harsh World**
#
# The city is a masterpiece of bio-dome and subterranean architecture, designed to protect its inhabitants from the Moon's lethal environment: vacuum, solar radiation, and micrometeorites.
#
# *   **The Grand Domes:** The most iconic features are the massive, transparent **geodesic domes** made from fused lunar regolith (moon dust) or incredibly strong, multi-layered plastics. These domes are covered with a thin layer of regolith for radiation shielding, with clear sections offering breathtaking views of the starry sky and the beautiful, luminous Earth.
# *   **Sub-Surface Habitats:** The majority of the city's residential and industrial areas are built **underground** or into the sides of crater walls. This uses the Moon's own rock as a natural shield against radiation and micrometeorites. A network of tunnels, or "lunatubes" (lava tubes), connects different districts.
# *   **Modular Construction:** The city grew from interconnected modules, much like the International Space Station. These modules can be sealed off in case of emergencies, ensuring safety and redundancy.
# *   **Atmosphere and Pressure:** The entire city is pressurized to a comfortable Earth-like atmosphere (around 101.3 kPa, with a nitrogen-oxygen mix). The difference in pressure between the inside and the vacuum outside is what gives the domes their structural strength.
#
# #### **3. Life in Luna City**
#
# **Population:** A diverse population of around 10,000-50,000 permanent residents, including scientists, engineers, miners, hydroponic farmers, tourism operators, artists, and even families.
#
# **Gravity:** The Moon's gravity is 1/6th of Earth's. This has profound effects on daily life:
# *   Movement is bouncy and graceful. "Loping" is the preferred way to walk.
# *   Sports are revolutionized—imagine basketball with incredible dunks or a new game like "Low-G Lacrosse."
# *   Health is a priority. Residents must adhere to strict exercise regimens to counter muscle atrophy and bone density loss.
#
# **Economy:** Luna City is a hub for several key industries:
# *   **Helium-3 Mining:** Helium-3, an isotope rare on Earth but abundant in the lunar regolith, is the city's primary export. It is a potential fuel for future, clean nuclear fusion reactors on Earth.
# *   **Scientific Research:** Unique fields like lunar geology, astronomy (with telescopes on the far side, free from Earth's radio interference), and low-gravity biology thrive here.
# *   **Tourism:** Although expensive, tourism is a major industry. Visitors experience low-gravity fun, Earth-gazing, and guided tours of historic landing sites.
# *   **Manufacturing:** The vacuum and low gravity are ideal for manufacturing certain alloys, crystals, and pharmaceuticals that are impossible to make on Earth.
#
# **Culture and Society:**
# *   **"Lunies":** The nickname for permanent residents. They develop a unique cultural identity, often seeing themselves as rugged pioneers distinct from "Earthlings."
# *   **The "Earthrise":** The stunning view of Earth hanging in the black sky is a central cultural and spiritual touchstone.
# *   **Time:** The city runs on **Lunar Standard Time (LST)**, which is likely synchronized with a time zone on Earth (e.g., GMT) for convenience, as the traditional 24-hour day/night cycle doesn't apply.
# *   **Government:** As the capital, it hosts the seat of the **Lunar Governing Council**, a representative body that manages lunar affairs, though its relationship with Earth-based governments is complex and often a subject of political tension.
#
# #### **4. Key Landmarks and Districts**
#
# *   **Tranquility Plaza:** The city's central park, located under the largest dome. It features Earth-like grass, trees, and a pond, all made possible by advanced bio-engineering. At its center is a monument containing an actual Apollo 11 lunar module descent stage.
# *   **Armstrong Port:** The main spaceport, located a safe distance from the main habitation domes. It's a constant hub of activity with ships arriving from Earth, Martian colonies, and orbital stations.
# *   **The Shackleton Ice Works:** The massive industrial facility that harvests and processes water ice from the crater's depths. It's the most critical infrastructure in the city.
# *   **The Galileo Observatory:** A research center dedicated to astronomy, built on the far side of the Moon and connected by high-speed maglev train.
# *   **The Von Neumann University:** The Moon's premier institution for higher learning, specializing in xenogeology, space engineering, and exobiology.
#
# #### **5. Challenges and Future**
#
# Luna City is a testament to human ingenuity, but it is fragile. Its existence depends on a delicate balance of technology. A major systems failure—power, air, or water—could be catastrophic. Psychologically, residents face isolation and the psychological strain of being away from the home planet.
#
# The future of Luna City is one of expansion. Plans exist to build larger domes, tap into more lava tubes, and eventually become a self-sustaining city of millions, serving as the primary gateway for humanity's further exploration of the Solar System.
#
# In essence, **Luna City is more than a place; it is the embodiment of a new chapter for humanity—a permanent foothold on a new world.**
